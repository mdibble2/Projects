# %% [markdown]
# ## Shopping Plan

# %% [markdown]
# ### Import data for current suppliers

# %%
import pandas as pd
import requests 
import numpy as np
from bs4 import BeautifulSoup

# %%
current = pd.read_csv('suppliers.csv')
current
# Out:
#                   supplier
# 0                 Ivystone
# 1      Meissenburg Designs
# 2               Snark City
# 3          Chronicle Books
# 4       Workman Publishing
# 5              Mary Square
# 6                 Ellembee
# 7         Walton Wood Farm
# 8            Sapling Press
# 9              Knock Knock
# 10               Capabunga
# 11               Fish Kiss
# 12         Barefoot Dreams
# 13          Creative Co-Op
# 14             Adams & Co.
# 15            Spunky Fluff
# 16    Anne McGilvray & Co.
# 17            Design Ideas
# 18      Eric & Christopher
# 19            Karma Living
# 20           Sweet Gumball
# 21             Stash Style
# 22          Ella B Candles
# 23                   julio
# 24                 torched
# 25               socksmith
# 26  Cedar Mountain Studios
# 27                  Joules
# 28         Venture Imports
# 29                     WHD
# 30   Cheryl Stevens Studio
# 31             Half United
# 32                 Baizaar
# 33                 Gorjana
# 34              Chez Gague
# 35         Carina Paper Co
# 36             World Finds
# 37    Pretty Alright Goods
# 38         Cotn Collection
# 39            Reeves & Co.

# %% [markdown]
# ### Scape market website to find where these suppliers will be at market

# %%
#My inital try was with beautiful soup, but this did not return all the data on the webpage
bnum = 1
floornum = 20
url = 'https://www.americasmart.com/browse/#/exhibitor?market=23&building=' + str(bnum) + '&floor=' + str(floornum) 
response = requests.get(url)
print(url)

if response.ok == True:
    data = response.text
    #print (data)
    soup = BeautifulSoup(data, 'lxml')
    #print (soup.prettify())
    booths = soup.select('body')
    #print (booths)
    text = soup.find_all(text=True)
    #print(text)
# Out:
# https://www.americasmart.com/browse/#/exhibitor?market=23&building=1&floor=20

# %%
#found the correct url of the AJAX request using inspect tool in google chrome
#instructions under"javascript heavy websites" on 
#https://blog.hartleybrody.com/web-scraping-cheat-sheet/#useful-libraries
url = 'https://wem.americasmart.com/api/v1.2/Search/LinesAndPhotosByMarket?status=ACTIVE_AND_UPCOMING&marketID=23'
r = requests.get(url)
info = r.json()
print(info[1])
# Out:
# {'showroomName': 'Abbey & CA Gift', 'booths': [{'floorNum': 13, 'isPerm': True, 'building': 2.0, 'lateOptIn': None, 'meridianUID': '1335A', 'showMarketLateOptInDates': [{'showLateOptInDatesID': 14, 'showLateOptInDate': '2020-01-16T05:00:00Z'}], 'title': '1335A', 'boothID': 249415}], 'logo': '//wem.americasmart.com/convdata/amc/images/ExhibitorLogos/44FEE1FF-5056-86CF-980D4A62EACE696B.jpg', 'productLines': [{'exhibLineID': 294565, 'description': 'Cathedral Art Metal Co.'}, {'exhibLineID': 300361, 'description': 'Amazing Woman Collection'}, {'exhibLineID': 300362, 'description': 'Say it with Sass'}, {'exhibLineID': 300363, 'description': 'Advent Collection'}, {'exhibLineID': 300364, 'description': 'Grace Outpoured Coaster Mugs'}, {'exhibLineID': 300369, 'description': 'Professions'}, {'exhibLineID': 300373, 'description': 'Car Charms & Visor Clips'}, {'exhibLineID': 310947, 'description': 'Abbey & CA Gift'}], 'exhibitorID': 2189}

# %%
#narrowing down all suppliers in one show room
for j in range(0,len(info[1]['productLines'])):
    print(info[1]['productLines'][j]['description'])

#played around with indexing to find the data I needed
info[1]['booths'][0]['title']
# Out:
# Cathedral Art Metal Co.
# Amazing Woman Collection
# Say it with Sass
# Advent Collection
# Grace Outpoured Coaster Mugs
# Professions
# Car Charms & Visor Clips
# Abbey & CA Gift
# '1335A'

# %%
allbooths = []

for i in range(0, len(info)):
    loc = info[i] #select the item in the list provided by the AJAX query
    for j in range(0,len(info[i]['productLines'])):  #some booths have multiple lines, which is why we need 2 for loops
        
        booth = loc['showroomName'] 
        boothid = loc['booths'][0]['title']
        line = info[i]['productLines'][j]['description']
        bldg = int(loc['booths'][0]['building']) 
        floor = loc['booths'][0]['floorNum']

        sublist1 = [line,bldg,floor,booth,boothid] #want there to be a separate record if this line is in a booth with another title
        sublist2 = [booth,bldg,floor,booth,boothid] #also want to capture lines that have their own booth
        allbooths.append(sublist1)
        allbooths.append(sublist2)

df = pd.DataFrame(allbooths,columns=['supplier','building','floor','booth','id'])

# %%
df.head()
# Out:
#                    supplier  building  floor                  booth     id
# 0     Moby Dick Specialties         2     10  Moby Dick Specialties   1029
# 1     Moby Dick Specialties         2     10  Moby Dick Specialties   1029
# 2   Cathedral Art Metal Co.         2     13        Abbey & CA Gift  1335A
# 3           Abbey & CA Gift         2     13        Abbey & CA Gift  1335A
# 4  Amazing Woman Collection         2     13        Abbey & CA Gift  1335A

# %%
df2 = df.drop_duplicates()

# %%
#sanity check on data by searching for a value I know is in the csv file
df2[df2['supplier']=="Snark City"]
# Out:
#         supplier  building  floor                booth    id
# 1766  Snark City         2     17  Just Got 2 Have It!  1709

# %%
#merge the two datasets together to combine the desired suppliers with their locations
merge = current.merge(df2)
merge
# Out:
#                   supplier  building  floor                         booth  \
# 0                 Ivystone         2     18                      Ivystone
# 1      Meissenburg Designs         2      7           Meissenburg Designs
# 2               Snark City         2     17           Just Got 2 Have It!
# 3          Chronicle Books         2     16           Simblist Group, The
# 4       Workman Publishing         2     17      Anne McGilvray & Company
# 5              Mary Square         2     18                      OneCoast
# 6              Mary Square         2      6                   Mary Square
# 7         Walton Wood Farm         2     15                  Road Runners
# 8            Sapling Press         2     16               daniel richards
# 9              Knock Knock         2     17           Just Got 2 Have It!
# 10               Capabunga         2     17          Dugan-Bliss & Assoc.
# 11               Fish Kiss         2      1                     Fish Kiss
# 12         Barefoot Dreams         2      9                    FIELDSTONE
# 13          Creative Co-Op         2     10                Creative Co-Op
# 14             Adams & Co.         2      6                   Adams & Co.
# 15            Spunky Fluff         2      7  Prairie Dance / Spunky Fluff
# 16            Design Ideas         2     16           Simblist Group, The
# 17            Design Ideas         2      8                  Design Ideas
# 18      Eric & Christopher         1      9            Eric & Christopher
# 19            Karma Living         1      9                  Karma Living
# 20           Sweet Gumball         1     11                 Sweet Gumball
# 21             Stash Style         1     10                   Stash Style
# 22          Ella B Candles         3      5                Ella B Candles
# 23  Cedar Mountain Studios         3      2        Cedar Mountain Studios
# 24                  Joules         3     11        Guy Bailey -Those Guys
# 25                  Joules         3     13               Brentwood Sales
# 26                  Joules         3     13                   Teacup Tots
# 27                  Joules         3      5               Portico Designs
# 28   Cheryl Stevens Studio         3      2         Cheryl Stevens Studio
# 29             Half United         3      4                   Half United
# 30                 Baizaar         3      4                       Baizaar
# 31                 Gorjana         3      4                       Gorjana
# 32         Carina Paper Co         3      2               Carina Paper Co
# 33    Pretty Alright Goods         3      2          Pretty Alright Goods
# 34         Cotn Collection         3      4               Cotn Collection
# 35            Reeves & Co.         3     11                  Reeves & Co.
#
#        id
# 0    1801
# 1    787B
# 2    1709
# 3    1621
# 4    1718
# 5    1800
# 6     621
# 7    1500
# 8    1634
# 9    1709
# 10   1701
# 11    231
# 12    912
# 13   1080
# 14   637A
# 15    796
# 16   1621
# 17   812B
# 18    C19
# 19    C15
# 20    E14
# 21     E6
# 22   1000
# 23    701
# 24   S117
# 25  E327B
# 26  W123A
# 27   2309
# 28    312
# 29   2913
# 30   2301
# 31   2802
# 32   2108
# 33   2107
# 34   2604
# 35   E112

# %%
#find any values that are in csv but not in the webscraped data--have to look at the rows after row 35
s1 = merge.supplier
s2 = current.supplier
s3 = s1.append(s2)
print(s3.drop_duplicates())
# Out:
# 0                   Ivystone
# 1        Meissenburg Designs
# 2                 Snark City
# 3            Chronicle Books
# 4         Workman Publishing
# 5                Mary Square
# 7           Walton Wood Farm
# 8              Sapling Press
# 9                Knock Knock
# 10                 Capabunga
# 11                 Fish Kiss
# 12           Barefoot Dreams
# 13            Creative Co-Op
# 14               Adams & Co.
# 15              Spunky Fluff
# 16              Design Ideas
# 18        Eric & Christopher
# 19              Karma Living
# 20             Sweet Gumball
# 21               Stash Style
# 22            Ella B Candles
# 23    Cedar Mountain Studios
# 24                    Joules
# 28     Cheryl Stevens Studio
# 29               Half United
# 30                   Baizaar
# 31                   Gorjana
# 32           Carina Paper Co
# 33      Pretty Alright Goods
# 34           Cotn Collection
# 35              Reeves & Co.
# 6                   Ellembee
# 16      Anne McGilvray & Co.
# 23                     julio
# 24                   torched
# 25                 socksmith
# 28           Venture Imports
# 29                       WHD
# 34                Chez Gague
# 36               World Finds
# Name: supplier, dtype: object

# %%
#found typing errors in csv file
#import new, edited csv file
current2 = pd.read_csv('suppliers_v2.csv')
merge2 = current2.merge(df2)

# %%
#check all values are in both
#only one I couldn't correct was WHD
s1 = merge2.supplier
s2 = current2.supplier
s3 = s1.append(s2)
print(s3.drop_duplicates())
# Out:
# 0                     Ivystone
# 1          Meissenburg Designs
# 2                   Snark City
# 3              Chronicle Books
# 4           Workman Publishing
# 5                  Mary Square
# 7                Ellembee Home
# 8             Walton Wood Farm
# 9                Sapling Press
# 10                 Knock Knock
# 11                   Capabunga
# 12                   Fish Kiss
# 13             Barefoot Dreams
# 14              Creative Co-Op
# 15                 Adams & Co.
# 16                Spunky Fluff
# 17    Anne McGilvray & Company
# 18                Design Ideas
# 20          Eric & Christopher
# 21                Karma Living
# 22               Sweet Gumball
# 23                 Stash Style
# 24              Ella B Candles
# 25               Julio Designs
# 27            Torched Products
# 28            Socksmith Design
# 29      Cedar Mountain Studios
# 30                      Joules
# 34       Venture Imports, LLC
# 35       Cheryl Stevens Studio
# 36                 Half United
# 37                     Baizaar
# 38                     Gorjana
# 39                  Chez Gagne
# 41             Carina Paper Co
# 42                  WorldFinds
# 43        Pretty Alright Goods
# 44             Cotn Collection
# 45                Reeves & Co.
# 29                         WHD
# Name: supplier, dtype: object

# %%
merge2.sort_values(by=['building','floor'],inplace = True)
merge2
# Out:
#                     supplier  building  floor                         booth  \
# 20        Eric & Christopher         1      9            Eric & Christopher
# 21              Karma Living         1      9                  Karma Living
# 23               Stash Style         1     10                   Stash Style
# 22             Sweet Gumball         1     11                 Sweet Gumball
# 12                 Fish Kiss         2      1                     Fish Kiss
# 6                Mary Square         2      6                   Mary Square
# 15               Adams & Co.         2      6                   Adams & Co.
# 1        Meissenburg Designs         2      7           Meissenburg Designs
# 16              Spunky Fluff         2      7  Prairie Dance / Spunky Fluff
# 19              Design Ideas         2      8                  Design Ideas
# 13           Barefoot Dreams         2      9                    FIELDSTONE
# 14            Creative Co-Op         2     10                Creative Co-Op
# 8           Walton Wood Farm         2     15                  Road Runners
# 3            Chronicle Books         2     16           Simblist Group, The
# 9              Sapling Press         2     16               daniel richards
# 18              Design Ideas         2     16           Simblist Group, The
# 39                Chez Gagne         2     16               daniel richards
# 2                 Snark City         2     17           Just Got 2 Have It!
# 4         Workman Publishing         2     17      Anne McGilvray & Company
# 10               Knock Knock         2     17           Just Got 2 Have It!
# 11                 Capabunga         2     17          Dugan-Bliss & Assoc.
# 17  Anne McGilvray & Company         2     17      Anne McGilvray & Company
# 0                   Ivystone         2     18                      Ivystone
# 5                Mary Square         2     18                      OneCoast
# 7              Ellembee Home         2     18                  Darrah & Co.
# 29    Cedar Mountain Studios         3      2        Cedar Mountain Studios
# 34     Venture Imports, LLC          3      2         Venture Imports, LLC
# 35     Cheryl Stevens Studio         3      2         Cheryl Stevens Studio
# 41           Carina Paper Co         3      2               Carina Paper Co
# 42                WorldFinds         3      2                    WorldFinds
# 43      Pretty Alright Goods         3      2          Pretty Alright Goods
# 25             Julio Designs         3      4                 Julio Designs
# 28          Socksmith Design         3      4              Socksmith Design
# 36               Half United         3      4                   Half United
# 37                   Baizaar         3      4                       Baizaar
# 38                   Gorjana         3      4                       Gorjana
# 44           Cotn Collection         3      4               Cotn Collection
# 24            Ella B Candles         3      5                Ella B Candles
# 27          Torched Products         3      5              Torched Products
# 33                    Joules         3      5               Portico Designs
# 40                Chez Gagne         3      5                    Chez Gagne
# 26             Julio Designs         3      9                Andy Acers Co.
# 30                    Joules         3     11        Guy Bailey -Those Guys
# 45              Reeves & Co.         3     11                  Reeves & Co.
# 31                    Joules         3     13               Brentwood Sales
# 32                    Joules         3     13                   Teacup Tots
#
#        id
# 20    C19
# 21    C15
# 23     E6
# 22    E14
# 12    231
# 6     621
# 15   637A
# 1    787B
# 16    796
# 19   812B
# 13    912
# 14   1080
# 8    1500
# 3    1621
# 9    1634
# 18   1621
# 39   1634
# 2    1709
# 4    1718
# 10   1709
# 11   1701
# 17   1718
# 0    1801
# 5    1800
# 7    1813
# 29    701
# 34   1205
# 35    312
# 41   2108
# 42   1301
# 43   2107
# 25    901
# 28   1005
# 36   2913
# 37   2301
# 38   2802
# 44   2604
# 24   1000
# 27   2400
# 33   2309
# 40   2505
# 26  S115A
# 30   S117
# 45   E112
# 31  E327B
# 32  W123A

# %%
# reset the index and export
merge2.set_index(np.arange(0,46),inplace=True)
merge2.to_csv('Market_Plan.csv')
