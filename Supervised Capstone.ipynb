# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Purpose of Analysis
# The variable of interest is grad_150_rate, which is the percentage of students who graduated within 150% of the normal time.
#
# Some questions of interest are:
# *  Can we accurately predict the graduation rate for given information about a school?
# *  Have graduation rates changed over the years this data was collected?
# *  What qualities/metrics of a school are most correlated with graduation?
# *  Along with the last question, where should we target changes to improve schools and graduation rates?
# *  Are there certain qualitites of the individual student that are related to higher graduation rates?

# %% [markdown]
# ### Context of Data
#
# These datasets come from the Chronicle of Higher Education (https://www.chronicle.com/), with support from the Bill & Melinda Gates Foundation (https://www.gatesfoundation.org/). The data was accessed on the site data world website (https://data.world/databeats/college-completion).
#
# These datasets contain college completion data from 3,800 degree-granting institutions in the United States. The colleges included reported a first-time, full-time degree-seeking undergraduate cohort of at least 100 students at the undergraduate level in 2013, and awarded undergraduate degrees between 2011 and 2013. They also includes colleges and universities that met the same criteria in 2010.

# %% [markdown]
# ## Importing & Exploring Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
college = pd.read_csv('cc_institution_details.csv')
grads = pd.read_csv('cc_institution_grads.csv')

# %%
#inspect tables
print(college.info())
print(grads.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 61 columns):
# unitid                                  3798 non-null int64
# chronname                               3798 non-null object
# city                                    3798 non-null object
# state                                   3798 non-null object
# level                                   3798 non-null object
# control                                 3798 non-null object
# basic                                   3798 non-null object
# hbcu                                    94 non-null object
# flagship                                50 non-null object
# long_x                                  3798 non-null float64
# lat_y                                   3798 non-null float64
# site                                    3779 non-null object
# student_count                           3798 non-null int64
# awards_per_value                        3798 non-null float64
# awards_per_state_value                  3798 non-null float64
# awards_per_natl_value                   3798 non-null float64
# exp_award_value                         3798 non-null int64
# exp_award_state_value                   3798 non-null int64
# exp_award_natl_value                    3798 non-null int64
# exp_award_percentile                    3798 non-null int64
# ft_pct                                  3794 non-null float64
# fte_value                               3798 non-null int64
# fte_percentile                          3798 non-null int64
# med_sat_value                           1337 non-null float64
# med_sat_percentile                      1337 non-null float64
# aid_value                               3797 non-null float64
# aid_percentile                          3797 non-null float64
# endow_value                             2323 non-null float64
# endow_percentile                        2323 non-null float64
# grad_100_value                          3467 non-null float64
# grad_100_percentile                     3467 non-null float64
# grad_150_value                          3467 non-null float64
# grad_150_percentile                     3467 non-null float64
# pell_value                              3797 non-null float64
# pell_percentile                         3797 non-null float64
# retain_value                            3535 non-null float64
# retain_percentile                       3535 non-null float64
# ft_fac_value                            3785 non-null float64
# ft_fac_percentile                       3785 non-null float64
# vsa_year                                279 non-null float64
# vsa_grad_after4_first                   279 non-null float64
# vsa_grad_elsewhere_after4_first         279 non-null float64
# vsa_enroll_after4_first                 279 non-null float64
# vsa_enroll_elsewhere_after4_first       279 non-null float64
# vsa_grad_after6_first                   279 non-null float64
# vsa_grad_elsewhere_after6_first         279 non-null float64
# vsa_enroll_after6_first                 279 non-null float64
# vsa_enroll_elsewhere_after6_first       279 non-null float64
# vsa_grad_after4_transfer                270 non-null float64
# vsa_grad_elsewhere_after4_transfer      270 non-null float64
# vsa_enroll_after4_transfer              270 non-null float64
# vsa_enroll_elsewhere_after4_transfer    270 non-null float64
# vsa_grad_after6_transfer                270 non-null float64
# vsa_grad_elsewhere_after6_transfer      270 non-null float64
# vsa_enroll_after6_transfer              270 non-null float64
# vsa_enroll_elsewhere_after6_transfer    270 non-null float64
# state_sector_ct                         3798 non-null int64
# carnegie_ct                             3798 non-null int64
# counted_pct                             3372 non-null object
# nicknames                               310 non-null object
# cohort_size                             3467 non-null float64
# dtypes: float64(40), int64(10), object(11)
# memory usage: 1.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302102 entries, 0 to 1302101
# Data columns (total 10 columns):
# unitid           1302102 non-null int64
# year             1302102 non-null int64
# gender           1302102 non-null object
# race             1302102 non-null object
# cohort           1302102 non-null object
# grad_cohort      889380 non-null float64
# grad_100         410069 non-null float64
# grad_150         889380 non-null float64
# grad_100_rate    332061 non-null float64
# grad_150_rate    694869 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 99.3+ MB
# None

# %%
college.head()
#unit id is the primary key
# Out:
#    unitid                            chronname        city    state   level  \
# 0  100654               Alabama A&M University      Normal  Alabama  4-year
# 1  100663  University of Alabama at Birmingham  Birmingham  Alabama  4-year
# 2  100690                   Amridge University  Montgomery  Alabama  4-year
# 3  100706  University of Alabama at Huntsville  Huntsville  Alabama  4-year
# 4  100724             Alabama State University  Montgomery  Alabama  4-year
#
#                   control                                              basic  \
# 0                  Public  Masters Colleges and Universities--larger prog...
# 1                  Public  Research Universities--very high research acti...
# 2  Private not-for-profit            Baccalaureate Colleges--Arts & Sciences
# 3                  Public  Research Universities--very high research acti...
# 4                  Public  Masters Colleges and Universities--larger prog...
#
#   hbcu flagship     long_x  ...  vsa_enroll_elsewhere_after4_transfer  \
# 0    X      NaN -86.568502  ...                                  17.2
# 1  NaN      NaN -86.809170  ...                                   NaN
# 2  NaN      NaN -86.174010  ...                                   NaN
# 3  NaN      NaN -86.638420  ...                                   0.0
# 4    X      NaN -86.295677  ...                                   NaN
#
#   vsa_grad_after6_transfer  vsa_grad_elsewhere_after6_transfer  \
# 0                     36.4                                 5.6
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      0.0                                 0.0
# 4                      NaN                                 NaN
#
#    vsa_enroll_after6_transfer  vsa_enroll_elsewhere_after6_transfer  \
# 0                        17.2                                  11.1
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         0.0                                   0.0
# 4                         NaN                                   NaN
#
#    state_sector_ct  carnegie_ct  counted_pct  nicknames  cohort_size
# 0               13          386      99.7|07        NaN        882.0
# 1               13          106      56.0|07        UAB       1376.0
# 2               16          252     100.0|07        NaN          3.0
# 3               13          106      43.1|07        UAH        759.0
# 4               13          386      88.0|07        ASU       1351.0
#
# [5 rows x 61 columns]

# %%
grads.head()
#each row represents grad rates/class size for one school, one year, with one combo of 
#gender and race. gender=B and race=X represents the overal size and rates (all genders, all races)
# Out:
#    unitid  year gender race  cohort  grad_cohort  grad_100  grad_150  \
# 0  100760  2011      B    X  2y all        446.0      73.0     105.0
# 1  100760  2011      M    X  2y all        185.0       NaN      40.0
# 2  100760  2011      F    X  2y all        261.0       NaN      65.0
# 3  100760  2011      B    W  2y all        348.0       NaN      86.0
# 4  100760  2011      M    W  2y all        162.0       NaN      35.0
#
#    grad_100_rate  grad_150_rate
# 0           16.4           23.5
# 1            NaN           21.6
# 2            NaN           24.9
# 3            NaN           24.7
# 4            NaN           21.6

# %%
#eliminating the '4y other' cohort type to reduce complexity
grads.cohort.value_counts()
grads = grads[(grads.cohort == '4y bach')|(grads.cohort == '2y all')]

# %%
#merging two csv files, college table has unique primary key
df = pd.merge(college,grads,how='left',on = 'unitid')
print(len(df))
# Out:
# 790560

# %%
df[(df.unitid == 100654)&(df.year ==2011)&(df.race == 'X')]
#checking to make sure the tables merged correctly
# Out:
#    unitid               chronname    city    state   level control  \
# 0  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 1  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 2  100654  Alabama A&M University  Normal  Alabama  4-year  Public
#
#                                                basic hbcu flagship     long_x  \
# 0  Masters Colleges and Universities--larger prog...    X      NaN -86.568502
# 1  Masters Colleges and Universities--larger prog...    X      NaN -86.568502
# 2  Masters Colleges and Universities--larger prog...    X      NaN -86.568502
#
#    ...  cohort_size  year  gender  race   cohort  grad_cohort  grad_100  \
# 0  ...        882.0  2011       B     X  4y bach       1088.0     116.0
# 1  ...        882.0  2011       M     X  4y bach        516.0      27.0
# 2  ...        882.0  2011       F     X  4y bach        572.0      89.0
#
#    grad_150  grad_100_rate  grad_150_rate
# 0     345.0           10.7           31.7
# 1     130.0            5.2           25.2
# 2     215.0           15.6           37.6
#
# [3 rows x 70 columns]

# %%
continuous = df.select_dtypes(include=['float64'])
continuous = pd.concat([continuous,df.unitid],axis=1)
len(continuous.columns)
# Out:
# 46

# %%
continuous.hist(figsize=(30,25))
plt.tight_layout();

# %% [markdown]
# **Observations**
# *  all 'percentile' variables should have uniform distribution, but grad_100_percentile has a spike near 0
# *  grad cohort looks to be highly skewed right, perhaps largest school should not be included

# %%
#was the data collected for an even amount of schools each year?
plt.hist(df.year)
plt.title('number of observations per year');

# %%
yearly_rates = df.groupby(by='year')['grad_150_rate'].mean()
plt.plot(yearly_rates)
plt.yticks(np.arange(0,105,5))
plt.title('Mean graduation rate by year');

# %% [markdown]
# ### Data Cleaning

# %%
#checking for null values in continuous variables first
null = continuous.isna().sum()/len(df)
null[null > 0].sort_values()
# Out:
# aid_value                               0.000273
# aid_percentile                          0.000273
# pell_value                              0.000273
# pell_percentile                         0.000273
# ft_pct                                  0.001093
# ft_fac_percentile                       0.003347
# ft_fac_value                            0.003347
# retain_value                            0.062022
# retain_percentile                       0.062022
# cohort_size                             0.069536
# grad_100_value                          0.069536
# grad_100_percentile                     0.069536
# grad_150_value                          0.069536
# grad_150_percentile                     0.069536
# grad_150                                0.121790
# grad_cohort                             0.121790
# grad_150_rate                           0.279528
# endow_value                             0.370423
# endow_percentile                        0.370423
# grad_100                                0.491261
# grad_100_rate                           0.587219
# med_sat_value                           0.637158
# med_sat_percentile                      0.637158
# vsa_year                                0.923770
# vsa_enroll_elsewhere_after6_first       0.923770
# vsa_grad_elsewhere_after4_first         0.923770
# vsa_grad_elsewhere_after6_first         0.923770
# vsa_grad_after6_first                   0.923770
# vsa_enroll_elsewhere_after4_first       0.923770
# vsa_enroll_after4_first                 0.923770
# vsa_grad_after4_first                   0.923770
# vsa_enroll_after6_first                 0.923770
# vsa_grad_after4_transfer                0.926230
# vsa_grad_elsewhere_after4_transfer      0.926230
# vsa_enroll_elsewhere_after4_transfer    0.926230
# vsa_grad_after6_transfer                0.926230
# vsa_grad_elsewhere_after6_transfer      0.926230
# vsa_enroll_after6_transfer              0.926230
# vsa_enroll_elsewhere_after6_transfer    0.926230
# vsa_enroll_after4_transfer              0.926230
# dtype: float64

# %%
null[null > 0].sort_values().index
# Out:
# Index(['aid_value', 'aid_percentile', 'pell_value', 'pell_percentile',
#        'ft_pct', 'ft_fac_percentile', 'ft_fac_value', 'retain_value',
#        'retain_percentile', 'cohort_size', 'grad_100_value',
#        'grad_100_percentile', 'grad_150_value', 'grad_150_percentile',
#        'grad_150', 'grad_cohort', 'grad_150_rate', 'endow_value',
#        'endow_percentile', 'grad_100', 'grad_100_rate', 'med_sat_value',
#        'med_sat_percentile', 'vsa_year', 'vsa_enroll_elsewhere_after6_first',
#        'vsa_grad_elsewhere_after4_first', 'vsa_grad_elsewhere_after6_first',
#        'vsa_grad_after6_first', 'vsa_enroll_elsewhere_after4_first',
#        'vsa_enroll_after4_first', 'vsa_grad_after4_first',
#        'vsa_enroll_after6_first', 'vsa_grad_after4_transfer',
#        'vsa_grad_elsewhere_after4_transfer',
#        'vsa_enroll_elsewhere_after4_transfer', 'vsa_grad_after6_transfer',
#        'vsa_grad_elsewhere_after6_transfer', 'vsa_enroll_after6_transfer',
#        'vsa_enroll_elsewhere_after6_transfer', 'vsa_enroll_after4_transfer'],
#       dtype='object')

# %%
#we have 1259496 rows of data, can drop rows with small amounts of nulls with little effect
continuous.dropna(subset=['aid_value', 'aid_percentile', 'pell_value', 'pell_percentile',
       'ft_pct', 'ft_fac_percentile', 'ft_fac_value', 'retain_value',
       'retain_percentile', 'cohort_size', 'grad_100_value',
       'grad_100_percentile', 'grad_150_value', 'grad_150_percentile'],inplace=True)

#need to drop any rows that do not have our target variable
continuous.dropna(subset= ['grad_150_rate'],inplace=True)

#if amount of nulls > 90%, drop that column 
continuous.drop(columns= ['vsa_year', 'vsa_enroll_elsewhere_after6_first',
       'vsa_grad_elsewhere_after4_first', 'vsa_grad_elsewhere_after6_first',
       'vsa_grad_after6_first', 'vsa_enroll_elsewhere_after4_first',
       'vsa_enroll_after4_first', 'vsa_grad_after4_first',
       'vsa_enroll_after6_first', 'vsa_grad_after4_transfer',
       'vsa_grad_elsewhere_after4_transfer',
       'vsa_enroll_elsewhere_after4_transfer', 'vsa_grad_after6_transfer',
       'vsa_grad_elsewhere_after6_transfer', 'vsa_enroll_after6_transfer',
       'vsa_enroll_elsewhere_after6_transfer', 'vsa_enroll_after4_transfer'],inplace=True)

# %%
## re-checking for null values
null = continuous.isna().sum()/len(df)
print(null[null > 0].sort_values())
# Out:
# endow_value           0.194194
# endow_percentile      0.194194
# grad_100              0.298057
# grad_100_rate         0.298057
# med_sat_value         0.394255
# med_sat_percentile    0.394255
# dtype: float64

# %%
grouped = df.groupby(by='year',as_index=False).mean()
plt.plot(grouped.year,grouped.endow_value)
plt.show()
#no trend by year, 2012 had more data and slightly lower endow_value
#won't interpolate values

# %%
#looking at histograms from earlier,

#endow value is very skewed right, replace nulls with median
#endow percentile is uniformly distributed, replace nulls with 50% percentile
endow_med = continuous.endow_value.median()
continuous.endow_value.fillna(endow_med,inplace = True)
continuous.endow_percentile.fillna(50,inplace=True)

#since we are interested in grad 150, can drop grad 100 columns
continuous.drop(['grad_100','grad_100_rate'],inplace=True, axis=1)

#med_sat_value is normally distributed, replace nulls with mean
#med_sat_percentile is uniformly distributed, replace nulls with 50% percentile
continuous.med_sat_value.fillna(continuous.med_sat_value.median(),inplace=True)
continuous.med_sat_percentile.fillna(50,inplace=True)

# %%
continuous.describe()
# Out:
#               long_x          lat_y  awards_per_value  awards_per_state_value  \
# count  554995.000000  554995.000000     554995.000000           554995.000000
# mean      -91.086630      38.355134         22.103423               21.995768
# std        15.908915       4.871822          8.921035                6.071961
# min      -159.395966      19.699720          0.500000                3.200000
# 25%       -97.463479      34.736660         17.300000               18.400000
# 50%       -87.216018      39.188616         20.900000               21.700000
# 75%       -79.184391      41.737205         24.500000               23.700000
# max       -67.243306      71.324702        131.100000               59.900000
#
#        awards_per_natl_value         ft_pct  med_sat_value  \
# count          554995.000000  554995.000000  554995.000000
# mean               21.648878      70.979059    1058.785503
# std                 4.741992      24.941184      88.500891
# min                16.500000       3.800000     666.000000
# 25%                16.500000      47.800000    1050.000000
# 50%                21.500000      78.300000    1050.000000
# 75%                22.500000      93.500000    1050.000000
# max                32.800000     100.000000    1534.000000
#
#        med_sat_percentile      aid_value  aid_percentile  ...  \
# count       554995.000000  554995.000000   554995.000000  ...
# mean            51.002088    8714.775360       53.287794  ...
# std             19.042237    6972.306361       28.141939  ...
# min              0.000000     294.000000        0.000000  ...
# 25%             50.000000    4113.000000       30.000000  ...
# 50%             50.000000    5722.000000       54.000000  ...
# 75%             50.000000   11614.000000       78.000000  ...
# max            100.000000   41580.000000      100.000000  ...
#
#        pell_percentile   retain_value  retain_percentile   ft_fac_value  \
# count    554995.000000  554995.000000      554995.000000  554995.000000
# mean         46.765238      67.819223          51.461411      48.172188
# std          28.307460      14.821545          28.186511      23.464310
# min           0.000000       0.000000           0.000000       0.000000
# 25%          22.000000      57.500000          28.000000      29.300000
# 50%          45.000000      68.100000          52.000000      45.600000
# 75%          71.000000      78.600000          76.000000      65.200000
# max         100.000000     100.000000         100.000000     100.000000
#
#        ft_fac_percentile    cohort_size    grad_cohort       grad_150  \
# count      554995.000000  554995.000000  554995.000000  554995.000000
# mean           50.994931     811.509014     159.328715      74.525515
# std            28.143649    1027.072593     383.831449     236.206147
# min             0.000000       1.000000       0.000000       0.000000
# 25%            27.000000     226.000000       5.000000       1.000000
# 50%            51.000000     464.000000      25.000000       8.000000
# 75%            75.000000     986.000000     148.000000      52.000000
# max            99.000000   16229.000000   18003.000000   11367.000000
#
#        grad_150_rate         unitid
# count  554995.000000  554995.000000
# mean       39.655610  201360.766329
# std        29.667048   81261.061969
# min         0.000000  100654.000000
# 25%        14.500000  151324.000000
# 50%        36.800000  189574.000000
# 75%        60.200000  219790.000000
# max       100.000000  474881.000000
#
# [8 rows x 27 columns]

# %%
plt.hist(continuous.grad_cohort);

# %%
#cohort size and grad cohort have huge outliers
#could skew models, so drop this observation

continuous = continuous[continuous.grad_cohort < 5000]

# %%
plt.hist(continuous.grad_100_percentile);
#this was a variable of concern when plotting all histograms
#data cleaning up to this point has made the distribution more uniform, so no action needed

# %%
print(df.describe().grad_150_rate)
print(continuous.describe().grad_150_rate)

#dropping null values and some additional rows did not dramatically change distribution of target variable
# Out:
# count    569576.000000
# mean         39.612532
# std          29.794769
# min           0.000000
# 25%          14.300000
# 50%          36.700000
# 75%          60.300000
# max         100.000000
# Name: grad_150_rate, dtype: float64
# count    554703.000000
# mean         39.639662
# std          29.663669
# min           0.000000
# 25%          14.500000
# 50%          36.800000
# 75%          60.100000
# max         100.000000
# Name: grad_150_rate, dtype: float64

# %%
#looking for other outliers
continuous_labels = list(continuous.columns)

i = 1
plt.figure(figsize=(15,30))
for var in continuous_labels: #plotting boxplot for each variable to examine outliers
  plt.subplot(round(len(continuous_labels),0)/3+3,4,i)
  plt.boxplot(continuous[var],whis=5)
  plt.title(var)
  i+=1
plt.tight_layout()
plt.show()

#some skewed distributions/outliers , might come back and winsorize later

# %% [markdown]
# Moving on to analysis/cleaning of categorical variables

# %%
cat = df.select_dtypes(include=['object','int64'])
cat = pd.concat([cat,df.unitid],axis=1)
cat.head()
# Out:
#    unitid               chronname    city    state   level control  \
# 0  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 1  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 2  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 3  100654  Alabama A&M University  Normal  Alabama  4-year  Public
# 4  100654  Alabama A&M University  Normal  Alabama  4-year  Public
#
#                                                basic hbcu flagship  \
# 0  Masters Colleges and Universities--larger prog...    X      NaN
# 1  Masters Colleges and Universities--larger prog...    X      NaN
# 2  Masters Colleges and Universities--larger prog...    X      NaN
# 3  Masters Colleges and Universities--larger prog...    X      NaN
# 4  Masters Colleges and Universities--larger prog...    X      NaN
#
#             site  ...  fte_percentile  state_sector_ct  carnegie_ct  \
# 0  www.aamu.edu/  ...              33               13          386
# 1  www.aamu.edu/  ...              33               13          386
# 2  www.aamu.edu/  ...              33               13          386
# 3  www.aamu.edu/  ...              33               13          386
# 4  www.aamu.edu/  ...              33               13          386
#
#    counted_pct  nicknames  year  gender  race   cohort  unitid
# 0      99.7|07        NaN  2011       B     X  4y bach  100654
# 1      99.7|07        NaN  2011       M     X  4y bach  100654
# 2      99.7|07        NaN  2011       F     X  4y bach  100654
# 3      99.7|07        NaN  2011       B     W  4y bach  100654
# 4      99.7|07        NaN  2011       M     W  4y bach  100654
#
# [5 rows x 26 columns]

# %%
cat.describe(include=['O'])
#hbcu and flagship have way less observations
# Out:
#                      chronname     city       state   level control  \
# count                   790560   790560      790560  790560  790560
# unique                    3793     1787          51       2       3
# top     Metro Business College  Chicago  California  4-year  Public
# freq                       648     8316       71550  479466  334260
#
#                                  basic   hbcu flagship              site  \
# count                           790560  19818    10800            787266
# unique                              33      1        1              3333
# top     Associates--Private For-profit      X        X  www.itt-tech.edu
# freq                            108756  19818    10800             18090
#
#        counted_pct nicknames  gender    race   cohort
# count       713286     66960  790560  790560   790560
# unique        1344       274       3       6        2
# top       100.0|07       NSU       B       A  4y bach
# freq         19980      1080  263520  131760   468936

# %%
cat.select_dtypes(include=['int64']).describe()
# Out:
#               unitid  student_count  exp_award_value  exp_award_state_value  \
# count  790560.000000  790560.000000     7.905600e+05          790560.000000
# mean   219165.401981    4611.445970     6.525195e+04           61546.978347
# std     98925.419975    7472.388022     1.088123e+05           33440.157310
# min    100654.000000      23.000000     0.000000e+00           12346.000000
# 25%    154262.000000     631.750000     3.221600e+04           35830.000000
# 50%    196069.500000    1879.000000     5.063400e+04           54322.000000
# 75%    230603.000000    5332.000000     7.723000e+04           79310.000000
# max    475291.000000  170144.000000     5.282095e+06          188870.000000
#
#        exp_award_natl_value  exp_award_percentile      fte_value  \
# count         790560.000000         790560.000000  790560.000000
# mean           61315.853962             49.863251    3827.494536
# std            29968.419979             28.962999    6075.265072
# min            24795.000000              0.000000      33.000000
# 25%            37780.000000             25.000000     680.000000
# 50%            38763.000000             50.000000    1682.000000
# 75%           101725.000000             75.000000    4302.000000
# max           101725.000000            100.000000  126411.000000
#
#        fte_percentile  state_sector_ct    carnegie_ct           year  \
# count   790560.000000    790560.000000  790560.000000  790560.000000
# mean        50.769604        34.434016     235.680943    2007.556557
# std         28.750366        28.335033     156.682232       3.467939
# min          0.000000         1.000000       1.000000    2002.000000
# 25%         26.000000        14.000000     106.000000    2005.000000
# 50%         51.000000        25.000000     169.000000    2008.000000
# 75%         76.000000        48.000000     343.000000    2011.000000
# max        100.000000       116.000000     517.000000    2013.000000
#
#               unitid
# count  790560.000000
# mean   219165.401981
# std     98925.419975
# min    100654.000000
# 25%    154262.000000
# 50%    196069.500000
# 75%    230603.000000
# max    475291.000000

# %%
cat.select_dtypes(include=['int64']).hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %%
#reformat hbcu and flagship (has NaN when variable value is false)
df.hbcu.fillna(1,inplace=True)
df.flagship.fillna(1,inplace=True)

df.loc[df.hbcu == 'X' , 'hbcu' ] = 2
df.loc[df.flagship == 'X' , 'flagship' ] = 2

cat = df.select_dtypes(include=['object','int64'])

# %%
#reformatting counted_pct
split = cat.counted_pct.str.split('|',expand=True)
print(split)
cat.counted_pct = split.loc[:,0].astype('float')
# Out:
#            0    1
# 0       99.7   07
# 1       99.7   07
# 2       99.7   07
# 3       99.7   07
# 4       99.7   07
# ...      ...  ...
# 790555   NaN  NaN
# 790556   NaN  NaN
# 790557   NaN  NaN
# 790558   NaN  NaN
# 790559   NaN  NaN
#
# [790560 rows x 2 columns]

# %%
#eliminate large outliers
cat = cat[cat.student_count < 50000]
cat = cat[cat.exp_award_value < 1000000]

# %%
#check distributions again
cat.select_dtypes(include=['int64']).hist(figsize=(12,10))
plt.tight_layout()
plt.show()

# %%
#don't need name of univeristy or their website, or id (will use indicies to join)
cat.drop(['chronname','site','nicknames','unitid'],axis=1,inplace=True)

#drop city for now becuase it will result in too many features, but could come back and create a variable with the info (like big city or town)
cat.drop(['city'],axis=1,inplace=True)

#drop redundant values in race and gender
cat = cat[(cat.gender == 'M') | (cat.gender == 'F')]
cat = cat[cat.race != 'X']

# %%
null = cat.isna().sum()/len(cat)
null[null>0].sort_values()
# Out:
# counted_pct    0.098094
# dtype: float64

# %%
#since this is a low percentage of rows, drop rows with nulls
cat.dropna(inplace=True)

# %%
print(len(cat))
print(len(continuous))
#comparing the number of observations left in each dataset
#expect merged dataset will have a row count <= 394,710
# Out:
# 394710
# 554703

# %%
#merging the two variable types back together, only where the index of the row is the same for both datasets
df_clean = pd.merge(continuous,cat,how='inner',left_index = True,right_index=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264867 entries, 4 to 790073
# Data columns (total 47 columns):
# long_x                    264867 non-null float64
# lat_y                     264867 non-null float64
# awards_per_value          264867 non-null float64
# awards_per_state_value    264867 non-null float64
# awards_per_natl_value     264867 non-null float64
# ft_pct                    264867 non-null float64
# med_sat_value             264867 non-null float64
# med_sat_percentile        264867 non-null float64
# aid_value                 264867 non-null float64
# aid_percentile            264867 non-null float64
# endow_value               264867 non-null float64
# endow_percentile          264867 non-null float64
# grad_100_value            264867 non-null float64
# grad_100_percentile       264867 non-null float64
# grad_150_value            264867 non-null float64
# grad_150_percentile       264867 non-null float64
# pell_value                264867 non-null float64
# pell_percentile           264867 non-null float64
# retain_value              264867 non-null float64
# retain_percentile         264867 non-null float64
# ft_fac_value              264867 non-null float64
# ft_fac_percentile         264867 non-null float64
# cohort_size               264867 non-null float64
# grad_cohort               264867 non-null float64
# grad_150                  264867 non-null float64
# grad_150_rate             264867 non-null float64
# unitid                    264867 non-null int64
# state                     264867 non-null object
# level                     264867 non-null object
# control                   264867 non-null object
# basic                     264867 non-null object
# hbcu                      264867 non-null int64
# flagship                  264867 non-null int64
# student_count             264867 non-null int64
# exp_award_value           264867 non-null int64
# exp_award_state_value     264867 non-null int64
# exp_award_natl_value      264867 non-null int64
# exp_award_percentile      264867 non-null int64
# fte_value                 264867 non-null int64
# fte_percentile            264867 non-null int64
# state_sector_ct           264867 non-null int64
# carnegie_ct               264867 non-null int64
# counted_pct               264867 non-null float64
# year                      264867 non-null int64
# gender                    264867 non-null object
# race                      264867 non-null object
# cohort                    264867 non-null object
# dtypes: float64(27), int64(13), object(7)
# memory usage: 97.0+ MB

# %%
df_clean.corr()
# Out:
#                           long_x     lat_y  awards_per_value  \
# long_x                  1.000000  0.131225          0.091968
# lat_y                   0.131225  1.000000          0.092990
# awards_per_value        0.091968  0.092990          1.000000
# awards_per_state_value  0.101216  0.137176          0.572021
# awards_per_natl_value   0.136082  0.038272          0.450451
# ft_pct                  0.196574  0.078730          0.257325
# med_sat_value           0.013297  0.082771          0.114077
# med_sat_percentile     -0.014436  0.073924          0.094499
# aid_value               0.170638  0.112847          0.135032
# aid_percentile          0.128089  0.072284          0.126844
# endow_value             0.057836  0.034064          0.055793
# endow_percentile        0.026541  0.069659          0.045293
# grad_100_value          0.180190  0.156845          0.376499
# grad_100_percentile     0.075762  0.165034          0.266055
# grad_150_value          0.146794  0.156030          0.376977
# grad_150_percentile    -0.006129  0.160352          0.238926
# pell_value              0.050017 -0.166022          0.102152
# pell_percentile         0.090792 -0.162251         -0.002275
# retain_value            0.063836  0.115895          0.175547
# retain_percentile      -0.061059  0.085900          0.080712
# ft_fac_value            0.051050 -0.038637          0.082154
# ft_fac_percentile      -0.054656 -0.125237          0.046451
# cohort_size             0.003935 -0.056197         -0.089394
# grad_cohort             0.018554 -0.021686         -0.028718
# grad_150                0.025910  0.005391          0.038880
# grad_150_rate           0.097590  0.063218          0.241081
# unitid                  0.093087  0.036639          0.120449
# hbcu                    0.057548 -0.128112         -0.138163
# flagship               -0.027381  0.036888          0.025707
# student_count          -0.151970 -0.103937         -0.183335
# exp_award_value         0.086933  0.084081         -0.110181
# exp_award_state_value   0.227935  0.148737          0.044823
# exp_award_natl_value    0.164710  0.087266          0.091602
# exp_award_percentile    0.057016  0.090642         -0.252280
# fte_value              -0.098421 -0.079984         -0.125569
# fte_percentile         -0.053337 -0.053850         -0.087038
# state_sector_ct        -0.101048 -0.100321         -0.121458
# carnegie_ct             0.097180  0.030653          0.263038
# counted_pct             0.309988  0.076241          0.179240
# year                    0.000792 -0.004699          0.012473
#
#                         awards_per_state_value  awards_per_natl_value  \
# long_x                                0.101216               0.136082
# lat_y                                 0.137176               0.038272
# awards_per_value                      0.572021               0.450451
# awards_per_state_value                1.000000               0.783841
# awards_per_natl_value                 0.783841               1.000000
# ft_pct                                0.505237               0.630814
# med_sat_value                         0.067832               0.066594
# med_sat_percentile                    0.038655               0.026799
# aid_value                             0.242083               0.315430
# aid_percentile                        0.167424               0.120912
# endow_value                           0.072123               0.098565
# endow_percentile                      0.028195               0.036742
# grad_100_value                        0.405825               0.448640
# grad_100_percentile                   0.100039              -0.000609
# grad_150_value                        0.432179               0.507931
# grad_150_percentile                   0.059344              -0.011164
# pell_value                            0.213461               0.224467
# pell_percentile                       0.033386              -0.002393
# retain_value                          0.186053               0.265143
# retain_percentile                    -0.030661              -0.032789
# ft_fac_value                          0.139317               0.193869
# ft_fac_percentile                     0.005964              -0.010362
# cohort_size                          -0.131057              -0.139505
# grad_cohort                          -0.045669              -0.045515
# grad_150                              0.031757               0.042275
# grad_150_rate                         0.285118               0.340099
# unitid                                0.234797               0.251276
# hbcu                                 -0.028156               0.014201
# flagship                             -0.005016               0.029784
# student_count                        -0.257864              -0.255636
# exp_award_value                       0.102267               0.199626
# exp_award_state_value                 0.135840               0.296484
# exp_award_natl_value                  0.221956               0.333546
# exp_award_percentile                 -0.014356               0.087078
# fte_value                            -0.167891              -0.157398
# fte_percentile                       -0.041739               0.015383
# state_sector_ct                      -0.164134              -0.059027
# carnegie_ct                           0.410147               0.483457
# counted_pct                           0.374990               0.480456
# year                                  0.028143               0.034919
#
#                           ft_pct  med_sat_value  med_sat_percentile  \
# long_x                  0.196574       0.013297           -0.014436
# lat_y                   0.078730       0.082771            0.073924
# awards_per_value        0.257325       0.114077            0.094499
# awards_per_state_value  0.505237       0.067832            0.038655
# awards_per_natl_value   0.630814       0.066594            0.026799
# ft_pct                  1.000000       0.231132            0.190282
# med_sat_value           0.231132       1.000000            0.916584
# med_sat_percentile      0.190282       0.916584            1.000000
# aid_value               0.599065       0.490743            0.318338
# aid_percentile          0.336999       0.304192            0.268435
# endow_value             0.232740       0.509816            0.331990
# endow_percentile        0.224319       0.463757            0.454661
# grad_100_value          0.642549       0.557427            0.468989
# grad_100_percentile     0.276364       0.472242            0.481615
# grad_150_value          0.714037       0.528425            0.461784
# grad_150_percentile     0.277121       0.514684            0.525110
# pell_value             -0.079304      -0.445791           -0.416821
# pell_percentile        -0.068338      -0.476705           -0.478471
# retain_value            0.527800       0.488098            0.440215
# retain_percentile       0.156978       0.509478            0.510553
# ft_fac_value            0.513221       0.287387            0.272802
# ft_fac_percentile       0.250186       0.272217            0.280055
# cohort_size             0.089809       0.261477            0.344592
# grad_cohort             0.063347       0.119100            0.154820
# grad_150                0.158742       0.204627            0.221964
# grad_150_rate           0.444333       0.358036            0.305426
# unitid                  0.080974      -0.034714           -0.026425
# hbcu                    0.086703      -0.211705           -0.222533
# flagship                0.117670       0.189657            0.245961
# student_count          -0.183384       0.148984            0.231665
# exp_award_value         0.434654       0.458174            0.312755
# exp_award_state_value   0.558002       0.177982            0.060037
# exp_award_natl_value    0.636429       0.188987            0.070776
# exp_award_percentile    0.181891       0.284606            0.261802
# fte_value              -0.032855       0.210948            0.292760
# fte_percentile          0.047196       0.316986            0.323272
# state_sector_ct        -0.060075       0.099116            0.028608
# carnegie_ct             0.272487      -0.134057           -0.158477
# counted_pct             0.760192       0.274009            0.214432
# year                    0.005777      -0.013161           -0.012820
#
#                         aid_value  aid_percentile  ...  exp_award_value  \
# long_x                   0.170638        0.128089  ...         0.086933
# lat_y                    0.112847        0.072284  ...         0.084081
# awards_per_value         0.135032        0.126844  ...        -0.110181
# awards_per_state_value   0.242083        0.167424  ...         0.102267
# awards_per_natl_value    0.315430        0.120912  ...         0.199626
# ft_pct                   0.599065        0.336999  ...         0.434654
# med_sat_value            0.490743        0.304192  ...         0.458174
# med_sat_percentile       0.318338        0.268435  ...         0.312755
# aid_value                1.000000        0.529062  ...         0.633222
# aid_percentile           0.529062        1.000000  ...         0.281743
# endow_value              0.529189        0.245916  ...         0.628869
# endow_percentile         0.327820        0.309082  ...         0.349699
# grad_100_value           0.727851        0.381818  ...         0.462026
# grad_100_percentile      0.329799        0.363870  ...         0.187390
# grad_150_value           0.679944        0.338953  ...         0.437421
# grad_150_percentile      0.327455        0.306343  ...         0.207696
# pell_value              -0.366081       -0.047050  ...        -0.277039
# pell_percentile         -0.247203       -0.045064  ...        -0.242986
# retain_value             0.571141        0.250112  ...         0.391031
# retain_percentile        0.287366        0.202762  ...         0.226404
# ft_fac_value             0.397030        0.259851  ...         0.360386
# ft_fac_percentile        0.206323        0.257771  ...         0.229025
# cohort_size             -0.052206        0.151021  ...         0.030221
# grad_cohort             -0.011757        0.072507  ...         0.024301
# grad_150                 0.085844        0.115731  ...         0.093376
# grad_150_rate            0.449687        0.244543  ...         0.304018
# unitid                  -0.096280       -0.021558  ...        -0.044437
# hbcu                    -0.022438       -0.004198  ...         0.102776
# flagship                -0.012495        0.109054  ...         0.068993
# student_count           -0.206907       -0.022650  ...        -0.085627
# exp_award_value          0.633222        0.281743  ...         1.000000
# exp_award_state_value    0.670853        0.144568  ...         0.480480
# exp_award_natl_value     0.741201        0.089138  ...         0.445366
# exp_award_percentile     0.231165        0.235857  ...         0.652688
# fte_value               -0.127319        0.059849  ...        -0.029348
# fte_percentile           0.165327        0.105700  ...         0.054105
# state_sector_ct          0.186832       -0.115358  ...         0.098458
# carnegie_ct              0.101235        0.017819  ...        -0.079500
# counted_pct              0.592537        0.344629  ...         0.441622
# year                    -0.016008       -0.013408  ...        -0.002338
#
#                         exp_award_state_value  exp_award_natl_value  \
# long_x                               0.227935              0.164710
# lat_y                                0.148737              0.087266
# awards_per_value                     0.044823              0.091602
# awards_per_state_value               0.135840              0.221956
# awards_per_natl_value                0.296484              0.333546
# ft_pct                               0.558002              0.636429
# med_sat_value                        0.177982              0.188987
# med_sat_percentile                   0.060037              0.070776
# aid_value                            0.670853              0.741201
# aid_percentile                       0.144568              0.089138
# endow_value                          0.265596              0.253586
# endow_percentile                     0.106158              0.069335
# grad_100_value                       0.515592              0.568711
# grad_100_percentile                  0.117400              0.088605
# grad_150_value                       0.543618              0.607542
# grad_150_percentile                  0.143024              0.108604
# pell_value                          -0.316285             -0.328259
# pell_percentile                     -0.149881             -0.090953
# retain_value                         0.511329              0.542527
# retain_percentile                    0.166554              0.090493
# ft_fac_value                         0.287387              0.384033
# ft_fac_percentile                    0.001606              0.057765
# cohort_size                         -0.003111             -0.072126
# grad_cohort                          0.008773             -0.015162
# grad_150                             0.082372              0.071046
# grad_150_rate                        0.335611              0.360753
# unitid                              -0.142642             -0.148603
# hbcu                                 0.026997              0.043980
# flagship                             0.021045              0.005332
# student_count                       -0.130831             -0.189152
# exp_award_value                      0.480480              0.445366
# exp_award_state_value                1.000000              0.788105
# exp_award_natl_value                 0.788105              1.000000
# exp_award_percentile                 0.157863             -0.008151
# fte_value                           -0.055514             -0.103273
# fte_percentile                       0.113795              0.079453
# state_sector_ct                      0.218491              0.147110
# carnegie_ct                          0.096298              0.136544
# counted_pct                          0.489954              0.535742
# year                                -0.012204             -0.014784
#
#                         exp_award_percentile  fte_value  fte_percentile  \
# long_x                              0.057016  -0.098421       -0.053337
# lat_y                               0.090642  -0.079984       -0.053850
# awards_per_value                   -0.252280  -0.125569       -0.087038
# awards_per_state_value             -0.014356  -0.167891       -0.041739
# awards_per_natl_value               0.087078  -0.157398        0.015383
# ft_pct                              0.181891  -0.032855        0.047196
# med_sat_value                       0.284606   0.210948        0.316986
# med_sat_percentile                  0.261802   0.292760        0.323272
# aid_value                           0.231165  -0.127319        0.165327
# aid_percentile                      0.235857   0.059849        0.105700
# endow_value                         0.255234  -0.032263        0.080732
# endow_percentile                    0.315835   0.093603        0.048231
# grad_100_value                      0.161325  -0.041554        0.135281
# grad_100_percentile                 0.068955   0.068008        0.040790
# grad_150_value                      0.131553   0.099390        0.184841
# grad_150_percentile                 0.086446   0.162740        0.160966
# pell_value                         -0.131071  -0.232816       -0.279612
# pell_percentile                    -0.219496  -0.185119       -0.319020
# retain_value                        0.139152   0.252847        0.307634
# retain_percentile                   0.177307   0.298301        0.377489
# ft_fac_value                        0.164176   0.162615        0.024786
# ft_fac_percentile                   0.161474   0.083758        0.016875
# cohort_size                         0.133952   0.904924        0.559881
# grad_cohort                         0.064019   0.386100        0.226894
# grad_150                            0.084006   0.356669        0.201736
# grad_150_rate                       0.112391   0.040720        0.121975
# unitid                              0.032871  -0.139478       -0.099770
# hbcu                                0.136094  -0.046087       -0.087277
# flagship                            0.148504   0.418481        0.164500
# student_count                       0.035589   0.968784        0.618504
# exp_award_value                     0.652688  -0.029348        0.054105
# exp_award_state_value               0.157863  -0.055514        0.113795
# exp_award_natl_value               -0.008151  -0.103273        0.079453
# exp_award_percentile                1.000000   0.056360        0.037476
# fte_value                           0.056360   1.000000        0.617325
# fte_percentile                      0.037476   0.617325        1.000000
# state_sector_ct                     0.046136  -0.031751        0.188930
# carnegie_ct                        -0.143346  -0.242537       -0.121152
# counted_pct                         0.240357  -0.061047        0.032026
# year                                0.004166  -0.027632       -0.022375
#
#                         state_sector_ct  carnegie_ct  counted_pct      year
# long_x                        -0.101048     0.097180     0.309988  0.000792
# lat_y                         -0.100321     0.030653     0.076241 -0.004699
# awards_per_value              -0.121458     0.263038     0.179240  0.012473
# awards_per_state_value        -0.164134     0.410147     0.374990  0.028143
# awards_per_natl_value         -0.059027     0.483457     0.480456  0.034919
# ft_pct                        -0.060075     0.272487     0.760192  0.005777
# med_sat_value                  0.099116    -0.134057     0.274009 -0.013161
# med_sat_percentile             0.028608    -0.158477     0.214432 -0.012820
# aid_value                      0.186832     0.101235     0.592537 -0.016008
# aid_percentile                -0.115358     0.017819     0.344629 -0.013408
# endow_value                    0.084709    -0.039329     0.283384 -0.005491
# endow_percentile              -0.010838    -0.091885     0.291726 -0.012989
# grad_100_value                 0.117110     0.166872     0.611967 -0.010076
# grad_100_percentile            0.034766    -0.008382     0.304758 -0.017149
# grad_150_value                 0.093265     0.189147     0.633354 -0.014632
# grad_150_percentile            0.131660    -0.056370     0.276515 -0.017640
# pell_value                    -0.181015     0.204032    -0.142055  0.040297
# pell_percentile               -0.158460     0.135080    -0.112124  0.014194
# retain_value                   0.183461     0.037973     0.469809 -0.026731
# retain_percentile              0.258073    -0.132603     0.161276 -0.020311
# ft_fac_value                  -0.093902     0.046006     0.476633 -0.022539
# ft_fac_percentile             -0.043172    -0.059778     0.264977 -0.010881
# cohort_size                   -0.079206    -0.228159     0.106841 -0.032714
# grad_cohort                   -0.046581    -0.090133     0.069963  0.017058
# grad_150                      -0.030762    -0.059444     0.142785  0.011569
# grad_150_rate                  0.084015     0.113212     0.401322  0.006108
# unitid                        -0.112534     0.114349     0.024462  0.064115
# hbcu                          -0.071313    -0.004278     0.086213 -0.000442
# flagship                      -0.119626    -0.135581     0.099444 -0.009095
# student_count                  0.024342    -0.275346    -0.175294 -0.028989
# exp_award_value                0.098458    -0.079500     0.441622 -0.002338
# exp_award_state_value          0.218491     0.096298     0.489954 -0.012204
# exp_award_natl_value           0.147110     0.136544     0.535742 -0.014784
# exp_award_percentile           0.046136    -0.143346     0.240357  0.004166
# fte_value                     -0.031751    -0.242537    -0.061047 -0.027632
# fte_percentile                 0.188930    -0.121152     0.032026 -0.022375
# state_sector_ct                1.000000    -0.033817    -0.054292 -0.009093
# carnegie_ct                   -0.033817     1.000000     0.220014  0.002700
# counted_pct                   -0.054292     0.220014     1.000000 -0.001386
# year                          -0.009093     0.002700    -0.001386  1.000000
#
# [40 rows x 40 columns]

# %%
#see which continuous variables are most heavily correlated with grad rate
df_clean.corr()['grad_150_rate'].sort_values()
# Out:
# pell_percentile          -0.232556
# pell_value               -0.228364
# hbcu                     -0.044565
# student_count            -0.038764
# unitid                   -0.028497
# year                      0.006108
# fte_value                 0.040720
# lat_y                     0.063218
# state_sector_ct           0.084015
# cohort_size               0.089286
# long_x                    0.097590
# flagship                  0.102857
# exp_award_percentile      0.112391
# carnegie_ct               0.113212
# grad_cohort               0.114097
# fte_percentile            0.121975
# ft_fac_percentile         0.188599
# grad_150                  0.212008
# awards_per_value          0.241081
# aid_percentile            0.244543
# endow_percentile          0.245903
# endow_value               0.264066
# awards_per_state_value    0.285118
# exp_award_value           0.304018
# med_sat_percentile        0.305426
# retain_percentile         0.307614
# ft_fac_value              0.322013
# exp_award_state_value     0.335611
# awards_per_natl_value     0.340099
# med_sat_value             0.358036
# exp_award_natl_value      0.360753
# grad_100_percentile       0.390922
# counted_pct               0.401322
# grad_150_percentile       0.411650
# ft_pct                    0.444333
# aid_value                 0.449687
# retain_value              0.472928
# grad_100_value            0.571552
# grad_150_value            0.597609
# grad_150_rate             1.000000
# Name: grad_150_rate, dtype: float64

# %% [markdown]
# ### Feature Engineering

# %%
from scipy.stats import pearsonr

# %%
#want to create a variable for describing student/faculty ratio

df_clean.ft_fac_value.hist();

# %%
df_clean.student_count.hist();

# %%
ft_stu_percentile = df_clean.student_count.sort_values() / df_clean.student_count.max() *100

# %%
ft_stu_percentile.hist();

# %%
#have the percentile of full time faculty
#want to make it a ratio to students

stu_fac_ratio = (np.array(ft_stu_percentile)+1)/(np.array(df_clean.ft_fac_percentile)+1)
pearsonr(stu_fac_ratio,df_clean.grad_150_rate)
#not significant
# Out:
# (-0.04298822089233851, 1.4840021952924568e-108)

# %%
pearsonr(ft_stu_percentile,df_clean.grad_150_rate)
#not significant alone either
# Out:
# (-0.03253144366016618, 5.981988450398105e-63)

# %% [markdown]
# Look for any interaction variables

# %%
#funding might have more of an effect depending on whether a school is public or private
school_type = pd.get_dummies(df_clean.control,drop_first=True)
school_type.head()
# Out:
#     Private not-for-profit  Public
# 4                        0       1
# 5                        0       1
# 7                        0       1
# 8                        0       1
# 10                       0       1

# %%
school_endowed = df_clean.endow_value * school_type['Private not-for-profit']
pearsonr(school_endowed,df_clean.grad_150_rate)
#endow value alone has correlation of .27 so this is not an improvement
# Out:
# (0.25906064399875034, 0.0)

# %%
school_aid = df_clean.aid_value * school_type['Private not-for-profit']
pearsonr(school_aid,df_clean.grad_150_rate)
#aid value alone has correlation of .47, so this is not an improvement
# Out:
# (0.4045011211306525, 0.0)

# %%
#one more idea: how do we treat students who transfer out of the university and graduate elsewhere?
#this data was dropped earlier due to large amnt of nulls


plt.hist(df_clean.grad_150_rate);
#why do some schools have a graduation rate so close to 0? 
#perhaps because students transfered and graduated elsewhere

# %%
df.vsa_grad_elsewhere_after6_transfer.describe() #swtiched to df, because in df_clean this variable was dropped
# Out:
# count    58320.000000
# mean         9.705926
# std          4.632650
# min         -9.000000
# 25%          7.500000
# 50%          9.700000
# 75%         11.900000
# max         32.000000
# Name: vsa_grad_elsewhere_after6_transfer, dtype: float64

# %% [markdown]
# only about 10% of the schools colleted this data (there's more info in the README file on VSA reporting)

# %%
#visualizing distribution of this variable 
plt.hist(df.vsa_grad_elsewhere_after6_transfer)
plt.title('Percentage of students who graduate elsewhere');
#negative value needs to be dropped because a negative is not possible

# %% [markdown]
# Strategy: fill in the transfer rate for colleges with NaN values with the mean value of transfer rate. Since this statistic is only collected for public schools, make a new variable for the interaction between public school type and transfer rate.

# %%
#dropping bad values (not null values though)
error = df.vsa_grad_elsewhere_after6_transfer[df.vsa_grad_elsewhere_after6_transfer <=0 ]
transfer = df.vsa_grad_elsewhere_after6_transfer.drop(error.index)

#concatenate vsa_grad_elsewhere_after6_transfer back in, only on indicies remaining in df_clean
df_clean = pd.concat([df_clean,transfer],axis=1,join='inner')
df_clean
#should be slightly smaller due to dropped rows with negative values
# Out:
#             long_x      lat_y  awards_per_value  awards_per_state_value  \
# 4       -86.568502  34.783368              14.2                    18.8
# 5       -86.568502  34.783368              14.2                    18.8
# 7       -86.568502  34.783368              14.2                    18.8
# 8       -86.568502  34.783368              14.2                    18.8
# 10      -86.568502  34.783368              14.2                    18.8
# ...            ...        ...               ...                     ...
# 790066 -117.568201  33.916750              12.9                    12.8
# 790067 -117.568201  33.916750              12.9                    12.8
# 790070 -117.568201  33.916750              12.9                    12.8
# 790072 -117.568201  33.916750              12.9                    12.8
# 790073 -117.568201  33.916750              12.9                    12.8
#
#         awards_per_natl_value  ft_pct  med_sat_value  med_sat_percentile  \
# 4                        21.5    93.8          823.0                 0.0
# 5                        21.5    93.8          823.0                 0.0
# 7                        21.5    93.8          823.0                 0.0
# 8                        21.5    93.8          823.0                 0.0
# 10                       21.5    93.8          823.0                 0.0
# ...                       ...     ...            ...                 ...
# 790066                   16.5    23.5         1050.0                50.0
# 790067                   16.5    23.5         1050.0                50.0
# 790070                   16.5    23.5         1050.0                50.0
# 790072                   16.5    23.5         1050.0                50.0
# 790073                   16.5    23.5         1050.0                50.0
#
#         aid_value  aid_percentile  ...  fte_value  fte_percentile  \
# 4          7142.0            72.0  ...       3906              33
# 5          7142.0            72.0  ...       3906              33
# 7          7142.0            72.0  ...       3906              33
# 8          7142.0            72.0  ...       3906              33
# 10         7142.0            72.0  ...       3906              33
# ...           ...             ...  ...        ...             ...
# 790066     1775.0             1.0  ...       4916              66
# 790067     1775.0             1.0  ...       4916              66
# 790070     1775.0             1.0  ...       4916              66
# 790072     1775.0             1.0  ...       4916              66
# 790073     1775.0             1.0  ...       4916              66
#
#         state_sector_ct  carnegie_ct  counted_pct  year  gender  race  \
# 4                    13          386         99.7  2011       M     W
# 5                    13          386         99.7  2011       F     W
# 7                    13          386         99.7  2011       M     B
# 8                    13          386         99.7  2011       F     B
# 10                   13          386         99.7  2011       M     H
# ...                 ...          ...          ...   ...     ...   ...
# 790066              113           81          5.9  2013       M     H
# 790067              113           81          5.9  2013       F     H
# 790070              113           81          5.9  2013       F    Ai
# 790072              113           81          5.9  2013       M     A
# 790073              113           81          5.9  2013       F     A
#
#          cohort  vsa_grad_elsewhere_after6_transfer
# 4       4y bach                                 5.6
# 5       4y bach                                 5.6
# 7       4y bach                                 5.6
# 8       4y bach                                 5.6
# 10      4y bach                                 5.6
# ...         ...                                 ...
# 790066   2y all                                 NaN
# 790067   2y all                                 NaN
# 790070   2y all                                 NaN
# 790072   2y all                                 NaN
# 790073   2y all                                 NaN
#
# [263763 rows x 48 columns]

# %%
#fillinf nulls 
df_clean.vsa_grad_elsewhere_after6_transfer.fillna(df_clean.vsa_grad_elsewhere_after6_transfer.mean(),inplace=True)

# %%
public = pd.get_dummies(df_clean.control,drop_first=True) #creating dummy variable for school type
public_transfer = df_clean.vsa_grad_elsewhere_after6_transfer * public.Public
pearsonr(public_transfer,df_clean.grad_150_rate)
#correlation is large enough to merit including this variable
# Out:
# (-0.32995878496102926, 0.0)

# %%
public_transfer.name = 'public_transfer_rate'

# %%
#add this new variable to the dataset
df_clean = pd.concat([df_clean,public_transfer],axis=1)

# %%
df_clean.isna().sum().sum()
#checking to make sure there are no nulls after manipulation and adding new variables
# Out:
# 0

# %% [markdown]
# **Since no other new features came to mind after brainstorming, moving on to prepare data for modeling**

# %%
#standardize X values since the scaling of variables are very different
from sklearn.preprocessing import StandardScaler

#Drop all related graduation metrics from df_clean, assume we have none of those in new observations
df_clean.drop(['grad_150','grad_150_value','grad_150_percentile','grad_100_value','grad_100_percentile'],axis=1,inplace=True) 

X = pd.get_dummies(df_clean,drop_first=True) #get dummy variables for X
variables = list(X.columns)

X.drop('grad_150_rate',axis=1,inplace=True) #drop target variable from X
X = StandardScaler().fit_transform(X) #Standardize X

variables.remove('grad_150_rate')

X = pd.DataFrame(X,columns=variables)
print('number of features: ',X.shape[1])
# Out:
# number of features:  127

# %%
from sklearn.model_selection import train_test_split

Y = StandardScaler().fit_transform(pd.DataFrame(df_clean.grad_150_rate)) #standardize Y

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=.2)

# %%
#verifying X and Y are expected shape
print(Y.shape)
print(X.shape)
# Out:
# (263763, 1)
# (263763, 127)

# %% [markdown]
# ## Models & Tuning Parameters with Randomized Grid Search
#
# 3 types of models were trained and compared, beginning first with a decision tree model due to its built in feature selection. Then, an ensemble version of this model was built with gradient boosting in efforts to improve performance. Finally, linear regression models were built based on the feature importances from the previous two models with goals to reduce computational complexity and overfitting.

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV
import time

dtree = DecisionTreeRegressor()
#grid to choose parameters from
parameters = { 
    'max_depth' : (2,10),  
    'min_samples_split' : (2,10),
    'max_features' : (5,20)
   }
start = time.time()
search = RandomizedSearchCV(dtree,parameters,n_iter=10,cv=10,n_jobs=-1) #use randomized grid search to speed up parameter optimization
model = search.fit(X_train,y_train) #fit model to training data
print('run time:',(time.time()-start)/60,'minutes')
# Out:
# run time: 0.586696183681488 minutes

# %%
model.best_params_
# Out:
# {'min_samples_split': 10, 'max_features': 20, 'max_depth': 10}

# %%
treemodel = DecisionTreeRegressor(min_samples_split=model.best_params_['min_samples_split'], 
                                  max_features=model.best_params_['max_features'], 
                                  max_depth=model.best_params_['max_depth'])
treemodel = treemodel.fit(X_train,y_train)

importance = pd.DataFrame(treemodel.feature_importances_,X_train.columns)
features = importance.sort_values(by=0)
features.tail(15) #show 15 most important features
# Out:
#                                0
# counted_pct             0.008296
# exp_award_value         0.008636
# race_B                  0.008721
# awards_per_natl_value   0.009071
# retain_percentile       0.009831
# race_W                  0.010706
# grad_cohort             0.010880
# aid_value               0.011257
# pell_value              0.011400
# awards_per_value        0.016801
# exp_award_natl_value    0.017797
# ft_pct                  0.028912
# med_sat_percentile      0.059784
# awards_per_state_value  0.067623
# retain_value            0.608391

# %% [markdown]
# Retain value is the share of freshmen that were retained for a second year, which has a strong relationship to the percentage of students who graduate in 6 years

# %%
from sklearn.model_selection import cross_val_score
train_r_1 = cross_val_score(treemodel,X_train,y_train,cv=10).mean()
test_r_1 = cross_val_score(treemodel,X_test,y_test,cv=10).mean()
print('train score:',train_r_1)
print('test score:', test_r_1)
# Out:
# train score: 0.3708181295645169
# test score: 0.3440648826364906

# %% [markdown]
# Further tuning -- pruning the decision tree

# %%
#pruning the tree down to 10 most important features
pruned = list(features.tail(10).index)
X_pruned = X[pruned]

X_train_p , X_test_p , y_train_p, y_test_p = train_test_split(X_pruned,Y)

pruned_tree = DecisionTreeRegressor()
parameters = {  
    'min_samples_split' : (2,5),
    'max_features' : (2,10)
   }
gs = RandomizedSearchCV(pruned_tree,parameters,n_iter=10,cv=10, n_jobs=-1)

dtree = gs.fit(X_train_p,y_train_p)
print(dtree.best_params_)
# Out:
# {'min_samples_split': 5, 'max_features': 2}

# %%
pruned_tree = DecisionTreeRegressor(max_features=2)

train_r_2 = cross_val_score(pruned_tree,X_train_p,y_train_p,cv=10).mean()
test_r_2 = cross_val_score(pruned_tree,X_test_p,y_test_p,cv=10).mean()
print('train score:',train_r_2)
print('test score:', test_r_2)

#decreased performance and increased variance
# Out:
# train score: 0.255659153850598
# test score: 0.10714617331623669

# %%
X_train.shape
# Out:
# (211010, 127)

# %%
y_train.shape
# Out:
# (211010, 1)

# %% [markdown]
# ### Random Forest with Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

forest = GradientBoostingRegressor(max_features=3,max_depth=8) #tuned through trial and error

start = time.time()
model2 = forest.fit(X_train,y_train) #start with pruned data to save computation time
time_elapsed = time.time()-start

# %%
print('run time:',time_elapsed/60,'minutes')
# Out:
# run time: 1.5513742804527282 minutes

# %%
train_r_3 = cross_val_score(model2,X_train,y_train,cv=5).mean()
test_r_3 = cross_val_score(model2,X_test,y_test,cv=5).mean()
print('train score:',train_r_3)
print('test score:', test_r_3)
# Out:
# train score: 0.42010652315743136
# test score: 0.39822368859414037

# %%
importance = pd.DataFrame(model2.feature_importances_,X_train.columns)
features = importance.sort_values(by=0)
features.tail(15) #show 15 most important features
# Out:
#                               0
# aid_value              0.019816
# pell_percentile        0.021172
# awards_per_natl_value  0.021274
# endow_value            0.024978
# ft_pct                 0.026637
# pell_value             0.028629
# aid_percentile         0.028631
# awards_per_value       0.028818
# public_transfer_rate   0.036994
# control_Public         0.039152
# med_sat_percentile     0.041213
# med_sat_value          0.074583
# exp_award_state_value  0.075179
# exp_award_value        0.079551
# retain_value           0.108023

# %% [markdown]
# ### OLS Linear Regression and Regularized Linear Regression Models

# %% [markdown]
# **Trying first with PCA**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#first check that there is not high multicolinearity between features since this is a requirement of PCA
correlation = X.corr()
columns = list(X.columns)
print(X.shape) #original shape
# Out:
# (263763, 127)

# %%
#attempt to start with df that is narrowed down by loan amount and keep reusing it
def cor ():
    df = correlation[(correlation['long_x']<0.80) & (correlation['long_x'] > - 0.80) & (correlation['long_x']!=1)]
    for i in columns:
        df = df[(df[i]<0.80) & (df[i] > - 0.80) | (df[i] == 1)] #keep rows for which the value is between -.8 and .8 OR the value is 1
        #otherwise, you delete every row by the end
    return df

cor() #number of rows remaining are the numer of features remaining after eliminating those with high multicolinearity
# Out:
#                           long_x     lat_y  awards_per_value  \
# lat_y                   0.131276  1.000000          0.093159
# awards_per_value        0.093116  0.093159          1.000000
# awards_per_state_value  0.103482  0.137275          0.572669
# awards_per_natl_value   0.136561  0.038331          0.451071
# ft_pct                  0.198401  0.078987          0.258740
# ...                          ...       ...               ...
# gender_M               -0.006783  0.000452         -0.006151
# race_Ai                -0.050534  0.022501         -0.034999
# race_B                  0.036198 -0.026688          0.009468
# race_H                 -0.005544 -0.008707         -0.005898
# race_W                  0.019011  0.008587          0.042088
#
#                         awards_per_state_value  awards_per_natl_value  \
# lat_y                                 0.137275               0.038331
# awards_per_value                      0.572669               0.451071
# awards_per_state_value                1.000000               0.784134
# awards_per_natl_value                 0.784134               1.000000
# ft_pct                                0.505206               0.631057
# ...                                        ...                    ...
# gender_M                             -0.007330              -0.011174
# race_Ai                              -0.057579              -0.079185
# race_B                                0.018159               0.030778
# race_H                               -0.000794              -0.000890
# race_W                                0.046046               0.048529
#
#                           ft_pct  med_sat_value  med_sat_percentile  \
# lat_y                   0.078987       0.082433            0.073370
# awards_per_value        0.258740       0.113683            0.094444
# awards_per_state_value  0.505206       0.069035            0.040066
# awards_per_natl_value   0.631057       0.066862            0.026800
# ft_pct                  1.000000       0.232840            0.191637
# ...                          ...            ...                 ...
# gender_M               -0.001329       0.001097            0.004647
# race_Ai                -0.031802       0.028977            0.037472
# race_B                  0.007317      -0.024433           -0.026920
# race_H                  0.002972       0.000801           -0.000254
# race_W                  0.004250      -0.025088           -0.029311
#
#                         aid_value  aid_percentile  ...  \
# lat_y                    0.113081        0.073203  ...
# awards_per_value         0.134796        0.127745  ...
# awards_per_state_value   0.242200        0.166675  ...
# awards_per_natl_value    0.315751        0.120838  ...
# ft_pct                   0.600449        0.336384  ...
# ...                           ...             ...  ...
# gender_M                -0.014734       -0.002442  ...
# race_Ai                 -0.023725        0.007839  ...
# race_B                  -0.001977       -0.003787  ...
# race_H                   0.009187        0.006446  ...
# race_W                  -0.013343       -0.022492  ...
#
#                         basic_Schools of engineering  basic_Schools of law  \
# lat_y                                       0.018592              0.002741
# awards_per_value                           -0.018824             -0.002169
# awards_per_state_value                      0.005178              0.007700
# awards_per_natl_value                       0.012859              0.004739
# ft_pct                                      0.026806             -0.018168
# ...                                              ...                   ...
# gender_M                                    0.003323             -0.002813
# race_Ai                                    -0.003446             -0.004135
# race_B                                     -0.001256              0.000666
# race_H                                     -0.001151             -0.003476
# race_W                                      0.000920              0.009417
#
#                         basic_Theological seminaries- Bible colleges- and other faith-related institutions  \
# lat_y                                                           -0.012232
# awards_per_value                                                 0.008639
# awards_per_state_value                                           0.045464
# awards_per_natl_value                                            0.052205
# ft_pct                                                           0.032092
# ...                                                                   ...
# gender_M                                                         0.020771
# race_Ai                                                         -0.027957
# race_B                                                          -0.010322
# race_H                                                          -0.012133
# race_W                                                           0.060990
#
#                         basic_Tribal Colleges  gender_M   race_Ai    race_B  \
# lat_y                                0.107317  0.000452  0.022501 -0.026688
# awards_per_value                    -0.044345 -0.006151 -0.034999  0.009468
# awards_per_state_value              -0.011233 -0.007330 -0.057579  0.018159
# awards_per_natl_value               -0.034202 -0.011174 -0.079185  0.030778
# ft_pct                              -0.021308 -0.001329 -0.031802  0.007317
# ...                                       ...       ...       ...       ...
# gender_M                            -0.001772  1.000000 -0.011149  0.007215
# race_Ai                              0.072803 -0.011149  1.000000 -0.215067
# race_B                              -0.025918  0.007215 -0.215067  1.000000
# race_H                              -0.025167  0.000281 -0.205979 -0.275011
# race_W                               0.012330  0.004832 -0.230556 -0.307825
#
#                           race_H    race_W  cohort_4y bach
# lat_y                  -0.008707  0.008587        0.062462
# awards_per_value       -0.005898  0.042088        0.092648
# awards_per_state_value -0.000794  0.046046        0.305258
# awards_per_natl_value  -0.000890  0.048529        0.490723
# ft_pct                  0.002972  0.004250        0.732613
# ...                          ...       ...             ...
# gender_M                0.000281  0.004832       -0.007955
# race_Ai                -0.205979 -0.230556       -0.026979
# race_B                 -0.275011 -0.307825       -0.003048
# race_H                  1.000000 -0.294817        0.004121
# race_W                 -0.294817  1.000000       -0.000088
#
# [111 rows x 127 columns]

# %%
df_no_mc = X[list(cor().index)]

# %% [markdown]
# deleting columns with high mutlicolinearity reduced effectiveness of model

# %%
#using PCA to narrow down the amount of features
pca_features = X
pca = PCA(n_components=15)
components = pca.fit_transform(pca_features) #data is already standardized

# %%
pca.explained_variance_ratio_
# Out:
# array([0.08072158, 0.05266753, 0.0264739 , 0.02528992, 0.02074312,
#        0.01822168, 0.01667967, 0.01577228, 0.01325603, 0.01236564,
#        0.0118853 , 0.01156186, 0.01116201, 0.01067047, 0.0103464 ])

# %%
plt.plot(np.arange(1,16),pca.explained_variance_ratio_)
plt.ylabel('% of variance explained')
plt.xlabel('number of pca components')
plt.title('elbow graph')
plt.show()

# %%
print(pca.explained_variance_ratio_.cumsum()[8])

#elbow (sharp slope change) at 8
# Out:
# 0.26982571499632824

# %%
pca_X = pd.DataFrame(components[:,:8])
pca_X
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.218664 -2.498922 -2.765949 -1.959319 -4.194596  0.875837 -1.424224
# 1       0.225712 -2.506695 -2.775727 -1.952665 -4.185263  0.854355 -1.428959
# 2       0.248097 -2.119358 -3.137553 -2.109290 -4.263269  0.886977 -1.681743
# 3       0.259058 -2.083058 -3.195452 -2.125210 -4.254476  0.859864 -1.707118
# 4       0.218990 -2.446253 -2.696013 -1.784163 -4.237086  0.899765 -1.354244
# ...          ...       ...       ...       ...       ...       ...       ...
# 263758 -3.804414  1.735720  1.598967  2.733058  2.013558  2.974122 -0.568066
# 263759 -3.796760  1.734786  1.581722  2.736209  2.022807  2.951767 -0.576004
# 263760 -3.852408  1.731276  1.726051  2.649469  1.965153  2.811369 -0.275848
# 263761 -3.817658  1.644315  1.680101  2.685422  2.010745  2.955973 -0.532895
# 263762 -3.809936  1.644141  1.662026  2.688185  2.019985  2.933521 -0.541189
#
#                7
# 0      -1.345916
# 1      -1.367164
# 2      -1.597490
# 3      -1.618959
# 4      -1.361691
# ...          ...
# 263758  2.110187
# 263759  2.088905
# 263760  1.954014
# 263761  2.019897
# 263762  1.998611
#
# [263763 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(pca_X,Y) 

lrm = LinearRegression().fit(X_train,y_train)

train_r_4 = cross_val_score(lrm,X_train,y_train,cv=10).mean()
test_r_4 = cross_val_score(lrm,X_test,y_test,cv=10).mean()
print('train score:',train_r_4)
print('test score:', test_r_4)

#model is not overfitting
# Out:
# train score: 0.3218816692918344
# test score: 0.32268300663531435

# %% [markdown]
# **Trying OLS without PCA**

# %%
#use the 7 most important features determined from decision tree
columns = list(features.tail(7).index)
columns
# Out:
# ['public_transfer_rate',
#  'control_Public',
#  'med_sat_percentile',
#  'med_sat_value',
#  'exp_award_state_value',
#  'exp_award_value',
#  'retain_value']

# %%
#look for outliers, make sure values make sense
X[columns].hist(figsize=(10,10));

# %%
from scipy.stats.mstats import winsorize
X_win = winsorize(X[columns],(0,.1)) #set limit on top 1% of data

# %%
#check for multicolinearity 
X[columns].corr()

#nothing over .8, so this is not an issue
# Out:
#                        public_transfer_rate  control_Public  \
# public_transfer_rate               1.000000        0.968010
# control_Public                     0.968010        1.000000
# med_sat_percentile                -0.043989       -0.041084
# med_sat_value                     -0.165147       -0.164643
# exp_award_state_value             -0.517544       -0.526834
# exp_award_value                   -0.348745       -0.358445
# retain_value                      -0.276153       -0.266719
#
#                        med_sat_percentile  med_sat_value  \
# public_transfer_rate            -0.043989      -0.165147
# control_Public                  -0.041084      -0.164643
# med_sat_percentile               1.000000       0.916626
# med_sat_value                    0.916626       1.000000
# exp_award_state_value            0.060456       0.178682
# exp_award_value                  0.314248       0.460024
# retain_value                     0.441135       0.489522
#
#                        exp_award_state_value  exp_award_value  retain_value
# public_transfer_rate               -0.517544        -0.348745     -0.276153
# control_Public                     -0.526834        -0.358445     -0.266719
# med_sat_percentile                  0.060456         0.314248      0.441135
# med_sat_value                       0.178682         0.460024      0.489522
# exp_award_state_value               1.000000         0.480787      0.511696
# exp_award_value                     0.480787         1.000000      0.391874
# retain_value                        0.511696         0.391874      1.000000

# %%
X_nomc = X[['public_transfer_rate',
 'med_sat_percentile',
 'med_sat_value',
 'exp_award_state_value',
 'exp_award_value',
 'retain_value']]
X_train2, X_test2 , y_train2 , y_test2 = train_test_split(X_nomc,Y) 
#tried with winsorized data , but scores were higher with regular data

# %%
lrm2 = LinearRegression().fit(X_train2,y_train2)

from sklearn.model_selection import cross_val_score
train_r_5 = cross_val_score(lrm2,X_train2,y_train2,cv=10).mean()
test_r_5 = cross_val_score(lrm2,X_test2,y_test2,cv=10).mean()
print('train score:',train_r_5)
print('test score:', test_r_5)
# Out:
# train score: 0.28758383411475513
# test score: 0.289190484393964

# %%
pd.DataFrame(lrm2.coef_[0],list(X_train2.columns))
#all positive relationships except the transfer rate
# Out:
#                               0
# public_transfer_rate  -0.192243
# med_sat_percentile     0.045291
# med_sat_value          0.109233
# exp_award_state_value  0.039641
# exp_award_value        0.031796
# retain_value           0.313632

# %% [markdown]
# ### Trying variations of linear regression

# %% [markdown]
# OLS regression model performs slightly better with PCA components, so we will use those moving forward

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
#Ridge Regression
ridge = Ridge()
alpha = {'alpha' : np.arange(1,200,10) } #parameters  to choose from

grid = RandomizedSearchCV(ridge,alpha,cv=10,n_iter=10) #cross-validated grid search to find best parameters
rr = grid.fit(X_train,y_train) #fit to training data
print(rr.best_params_)
# Out:
# {'alpha': 181}

# %%
train_r_6 = cross_val_score(rr,X_train,y_train,cv=10).mean()
test_r_6 = cross_val_score(rr,X_test,y_test,cv=10).mean()
print('train score:',train_r_6)
print('test score:', test_r_6)
# Out:
# train score: 0.32188170153660667
# test score: 0.32268305932527214

# %%
#Lasso Regression
lasso = Lasso()

grid2 = RandomizedSearchCV(lasso,alpha,cv=10,n_iter=10)
lr = grid2.fit(X_train,y_train)
print(lr.best_params_)
# Out:
# {'alpha': 111}

# %%
train_r_7 = cross_val_score(lr,X_train,y_train,cv=10).mean()
test_r_7 = cross_val_score(lr,X_test,y_test,cv=10).mean()
print('train score:',train_r_7)
print('test score:', test_r_7)
# Out:
# train score: 0.07324704256827816
# test score: 0.11160865402865414

# %%
#ElasticNet Regression
enet = ElasticNet()

params = {'alpha' : np.arange(1,200,10)  , 'l1_ratio' : [0,.25,.5,.75,1] }
grid3 = RandomizedSearchCV(enet,params,cv=10,n_iter=10)
enr = grid3.fit(X_train,y_train)
print(enr.best_params_)
# Out:
# {'l1_ratio': 0, 'alpha': 61}

# %%
train_r_8 = cross_val_score(enet,X_train,y_train,cv=10).mean()
test_r_8 = cross_val_score(enet,X_test,y_test,cv=10).mean()
print('train score:',train_r_8)
print('test score:', test_r_8)
# Out:
# train score: 0.25245463670314044
# test score: 0.2525542498060517

# %% [markdown]
# ## Model Comparison and Selection

# %%
#compare accuracy, variance, run times
test = np.array([test_r_1,test_r_2,test_r_3,test_r_4,test_r_5,test_r_6,test_r_7,test_r_8])
train = np.array([train_r_1,train_r_2,train_r_3,train_r_4,train_r_5,train_r_6,train_r_7,test_r_8])
train_minus_test = train - test

scores = pd.DataFrame([train,test,train_minus_test],
                      columns=['Decision Tree','Pruned Tree','Gradient Random Forest','Linear Reg PCA','Linear Reg','Ridge','Lasso','ElasticNet'],
                      index=['train score','test score','train - test']).T
scores
# Out:
#                         train score  test score  train - test
# Decision Tree              0.370818    0.344065      0.026753
# Pruned Tree                0.255659    0.107146      0.148513
# Gradient Random Forest     0.420107    0.398224      0.021883
# Linear Reg PCA             0.321882    0.322683     -0.000801
# Linear Reg                 0.287584    0.289190     -0.001607
# Ridge                      0.321882    0.322683     -0.000801
# Lasso                      0.073247    0.111609     -0.038362
# ElasticNet                 0.252554    0.252554      0.000000

# %% [markdown]
# **The Random Forest model had the highest performance on both the training and test data. The decision tree was close to the random forest with the training accuracy, but as expected, the decision tree overfit the data.**

# %% [markdown]
# Below is the code to get metrics on the error of the top 2 models, but it is too computationally heavy and kills the kernel each time it is run. If there was more time for this project, I would troubleshoot this issue

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# y_pred_tree = pruned_tree.fit(X_train_p,y_train).predict(X_test_p)
# error_tree = y_test - y_pred_tree

# y_pred_forest = forest.predict(X_test_p)
# error_forest = y_test - y_pred_forest

# print('decision tree MSE:', mean_squared_error(y_pred_tree,error_tree))
# print('random forest MSE:', mean_squared_error(y_pred_forest,error_forest))

# %%
# print('linear regression MAE:', mean_absolute_error(y_pred_tree,error_tree))
# print('ridge regression MAE:', mean_absolute_error(y_pred_forest,error_forest))

# %% [markdown]
# ## Analysis of Results and Comparison to Other Studies

# %%
features.tail(10)
# Out:
#                               0
# pell_value             0.028629
# aid_percentile         0.028631
# awards_per_value       0.028818
# public_transfer_rate   0.036994
# control_Public         0.039152
# med_sat_percentile     0.041213
# med_sat_value          0.074583
# exp_award_state_value  0.075179
# exp_award_value        0.079551
# retain_value           0.108023

# %% [markdown]
# **Most important features:**
# * Freshman retention rate
# * Estimated educational spending per degree (exp_award_state_value and exp_award_value)
# * Median SAT value (for incoming students)

# %% [markdown]
# **Important missing features (from other literature):**
# * Student GPA (first year)
# * Transfer information for non-public 4-year institutions
# * Percentage of faculty that are full time
# * Faculty Salary
#
# Having these features could increase scores for the models.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The feature importances show that freshmen retention, educational spending per student, and student achievement prior to college (measured by SAT scores) are the most related to higher 6 year graduation rates. While correlation does not indicate causation, this is a meaningful lesson for colleges questioning why they have low graduation rates, and can provide data to back decisions made by universities and  2 year colleges.
#
# Additionally, the overall low scores of all the models are indicative of how there are likely missing features from the data, and also how challenging it is to predict graduation rates when there are so many factors (each with variation) in play.
#
# For further study, it would be interesting to compare the feature importances with a model that has 4 year graduation rates as a target variable. Additionally, if possible, collecting some of the "missing features" stated above would be another good next step to improve this project.

# %% [markdown]
# References:
#
# Data Accessed On: https://data.world/databeats/college-completion
# Secondary Sources: https://www.chronicle.com/
# https://www.gatesfoundation.org/
# https://www.clarion.edu/about-clarion/offices-and-administration/university-support-and-business/office-of-institutional-research/retention-and-graduation-rate-analysis-clarion-university.pdf
# https://pdfs.semanticscholar.org/64f7/064c0d0d5b3417166e6e7ca9e4e157673eb2.pdf
